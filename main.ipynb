# %%
# For exploration and demo execution
what should the main.ipynb be for exploration and execution so that it produces everything in the @c:\Users\Impala\Downloads\draft5 (1).ipynb without the massive code
