# %% [markdown]
# # Title: Training the DenseNet121 + Metadata Fusion Model
# # Description: Trains the multimodal model using NIH/CheXpert, validates, and checkpoints.

# %%
from src.train import main as train_main

# Use local CSV paths created from previous notebook
train_csv = "data/processed/combined_train.csv"
val_csv = "data/processed/chexpert_processed.csv"
test_csv = "data/processed/rsna_processed.csv"

# Equivalent to running from command line:
# python -m src.train --train_csv data/... --val_csv data/... --test_csv data/...
# !python -m src.train --train_csv {train_csv} --val_csv {val_csv} --test_csv {test_csv} --epochs 10 --batch_size 32

# Note: Training logs and checkpoints will be stored in experiments/checkpoints/
